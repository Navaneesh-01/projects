# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv(r"C:\Users\NAVANEESH RR\Documents\Pandas practice\FiFa_Data_File.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
a = fifa["nationality"].value_counts()[0:5]
b = fifa["nationality"].value_counts()[0:5].keys()

# %%
plt.bar(b,a)
# Out:
# <BarContainer object of 5 artists>

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
f = fifa["short_name"][0:5]
g = fifa["age"]

# %%
plt.hist(g,bins=50)
plt.show()

# %%
b = fifa["age"].unique()
b
# Out:
# array([32, 34, 27, 26, 28, 33, 20, 25, 31, 30, 24, 29, 23, 19, 22, 37, 36,
#        21, 41, 38, 35, 18, 40, 39, 17, 16, 42], dtype=int64)

# %%
k = fifa["age"].value_counts()[0:10]

# %%
plt.pie(k,labels=fifa["age"][0:10],autopct="%0.1f%%")
plt.show()

# %%
player_salary = fifa[["short_name","wage_eur"]]

# %%
s = player_salary["short_name"][0:10]
h = player_salary["wage_eur"].value_counts()

# %%
plt.figure(figsize=(20,5))
plt.hist(h,bins=150)
plt.show()

# %%
player_salary.head(10)
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000
# 19          L. Suárez    355000
# 8           L. Modrić    340000
# 36           T. Kroos    330000
# 17          S. Agüero    300000
# 21    Sergio Busquets    300000

# %%
player_salary = player_salary.sort_values(by=["wage_eur"],ascending=False
                                         )

# %%
wn =fifa["nationality"] == "Germany"

# %%
Germany = fifa[wn]

# %%
Germany.head()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels          Mats  Hummels   30  1988-12-16        191
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# ...

# %%
LL =fifa["club"] == "Real Madrid"

# %%
Real_Madrid = fifa[LL]

# %%
Real_Madrid.head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28     192119  https://sofifa.com/player/192119/thibaut-court...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 28   T. Courtois     Thibaut Courtois   27  1992-05-11        199         96
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %%
Real_Madrid[["short_name","wage_eur"]].sort_values(by=["wage_eur"],ascending=False)
# Out:
#             short_name  wage_eur
# 4            E. Hazard    470000
# 8            L. Modrić    340000
# 36            T. Kroos    330000
# 18        Sergio Ramos    300000
# 46          K. Benzema    285000
# 100            G. Bale    250000
# 62                Isco    245000
# 42            Casemiro    240000
# 28         T. Courtois    235000
# 106       J. Rodríguez    225000
# 76           R. Varane    205000
# 94            Carvajal    205000
# 101            Marcelo    205000
# 53            K. Navas    195000
# 403      Lucas Vázquez    180000
# 178      Marco Asensio    180000
# 277    Nacho Fernández    165000
# 161           L. Jović    155000
# 636            Mariano    145000
# 424           F. Mendy    115000
# 437          Odriozola    115000
# 332       Éder Militão    105000
# 2286       Lucas Silva     88000
# 1009       F. Valverde     86000
# 568       Vinícius Jr.     60000
# 2652            Brahim     58000
# 1256           Rodrygo     47000
# ...

# %%
fifa["player_url"].drop
# Out:
# <bound method Series.drop of 0        https://sofifa.com/player/158023/lionel-messi/...
# 1        https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2        https://sofifa.com/player/190871/neymar-da-sil...
# 3        https://sofifa.com/player/200389/jan-oblak/20/...
# 4        https://sofifa.com/player/183277/eden-hazard/2...
#                                ...
# 18273    https://sofifa.com/player/245006/shuai-shao/20...
# 18274    https://sofifa.com/player/250995/mingjie-xiao/...
# 18275    https://sofifa.com/player/252332/wei-zhang/20/...
# 18276    https://sofifa.com/player/251110/haijian-wang/...
# 18277    https://sofifa.com/player/233449/ximing-pan/20...
# Name: player_url, Length: 18278, dtype: object>

# %%
fifa
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...
